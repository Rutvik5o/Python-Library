# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[2,5,7])
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[2,5,7])
plt.title("Practice data")
plt.ylabel("This is y")
plt.xlabel("This is x")
plt.show()

# %%
from matplotlib import style

style.use('ggplot')
x=[1,3,6]
y=[36,63,2]
x2=[54,33,22]
y2=[9,54,34]

plt.plot(x,y,label="first",linewidth=3) #you can give also linewidth= any
#plt.scatter(x,y,label="first",linewidth=3) #you can give also linewidth= any
#plt.hist(x,label="first",linewidth=3) #you can give also linewidth= any
plt.plot(x2,y2,label="second")
plt.legend() #should be pass explicity for show which color if first and which second from label on chart right side
plt.show()
